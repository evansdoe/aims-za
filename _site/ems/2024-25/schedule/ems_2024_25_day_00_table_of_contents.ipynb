# %% [markdown]
# <img src="./images/aims-za-logo.jpeg" alt="drawing" style="width:400px;"/>
# <h1 style="text-align: center;"><a title="EMS-AIMS-ZA-2024-25" href="https://evansdoe.github.io/aims-za/ems/2024-25">Experimental Mathematics Using SageMath — AIMS-ZA-2024-25</a></h1>
#
#
# This is a course on Experimental Mathematics using the computer algebra system — [SageMath](http://www.sagemath.org).
#
#
# ## Instructor:
#
# * <a href="http://evansdoe.github.io">**Evans Ocansey**</a>
#
# The outline of the this notebook is as follows:

# %% [markdown]
# ## Table of Contents: <a class="anchor" id="toc"></a>
# * [ ] [<font color=blue>Day 01 — Introduction to SageMath</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#day-01-introduction-to-sagemath)
#     * [ ] [<font color=blue>What is SageMath?</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#what-is-sagemath)
#         *  [<font color=blue>A Brief Overview</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#a-brief-overview)
#         * [<font color=blue>Using Other Non-Commercial Softwares</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#using-non-commerical-softwares)
#     * [ ] [<font color=blue>Help Inside SageMath</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#help-inside-sagemath)
#         *  [<font color=blue>Documentation</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#documetation)
#         *  [<font color=blue>Tab Completion</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#tab-completion)
#     * [ ] [<font color=blue>Complete Access to Source Code</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#access-to-source-code)
#         *  [<font color=green>Exercise 1</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#exercise-1)
#     * [ ] [<font color=blue>Just the Basics</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#just-the-basics)
#         *  [<font color=blue>Sage as a Calculator</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#sage-as-a-calculator)
#             *  [<font color=green>Exercise 2</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#exercise-2)
#         *  [<font color=blue>Elementary Functions and Usual Constants</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#elementary-functions-and-usual-constants)
#         *  [<font color=blue>Python Variables</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#python-variables)
#         *  [<font color=blue>Symbolic Variables</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#symbolic-variables)
#             *  [<font color=green>Exercise 3</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#exercise-3)
#         *  [<font color=blue>Linear Algebra — Some Basics</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#linear-algebra-some-basics)
#         *  [<font color=blue>Calculus — Some Basics</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#calculus-some-basics)
#         *  [<font color=blue>Plotting in Brief</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#plotting-in-brief)
#     * [ ] [<font color=blue>Demonstration of Some SageMath Components</font>](./ems_2024_25_day_01_sagemath_introduction.ipynb#demonstration-of-some-sagemath-components)
#
# * [ ]   [<font color=blue>Day 02 — Starting to Program</font>](./ems_2024_25_day_02_starting_to_program.ipynb#short-review-on-python-programming)
#     * [ ]   [<font color=blue>Section 1 of Day 02 notebook</font>](./ems_2024_25_day_02_title_of_notebook_day_02_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 02 notebook</font>](./ems_2024_25_day_02_title_of_notebook_day_02_notebook.ipynb#exercise-3)
#     * [ ]   [<font color=blue>Section 2 of Day 02 notebook</font>](./ems_2024_25_day_02_title_of_notebook_day_02_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 02 notebook</font>](./ems_2024_25_day_02_title_of_notebook_day_02_notebook.ipynb#exercise-4)
#
# * [ ]   [<font color=blue>Day 03 — New Experiment Sum of Squares and Plotting</font>](./ems_2024_25_day_03_sum_of_squares_and_plotting.ipynb#new-experiment-sum-of-squares-and-plotting)
#     * [ ]   [<font color=blue>Last Thoughts on the Conductors</font>](./ems_2024_25_day_03_sum_of_squares_and_plotting.ipynb#last-thoughts-on-the-conductor)
#     * [ ]   [<font color=blue>New Experiment — Sum of Squares</font>](./ems_2024_25_day_03_sum_of_squares_and_plotting.ipynb#new-experiment-sum-of-squares)
#     * [ ]   [<font color=blue>More Plotting and Graphics in Two Dimensions</font>](./ems_2024_25_day_03_sum_of_squares_and_plotting.ipynb#more-plotting-and-graphics-in-two-dimensions)
#
# * [ ]   [<font color=blue>Day 04 — title of day 04 notebook</font>](./ems_2024_25_day_04_title_of_notebook_day_04_notebook.ipynb#title-of-day-04-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 04 notebook</font>](./ems_2024_25_day_04_title_of_notebook_day_04_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 04 notebook</font>](./ems_2024_25_day_04_title_of_notebook_day_04_notebook.ipynb#exercise-7)
#     * [ ]   [<font color=blue>Section 2 of Day 04 notebook</font>](./ems_2024_25_day_04_title_of_notebook_day_04_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 04 notebook</font>](./ems_2024_25_day_04_title_of_notebook_day_04_notebook.ipynb#exercise-8)
#
# * [ ]   [<font color=blue>Day 05 — title of day 05 notebook</font>](./ems_2024_25_day_05_title_of_notebook_day_05_notebook.ipynb#title-of-day-05-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 05 notebook</font>](./ems_2024_25_day_05_title_of_notebook_day_05_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 05 notebook</font>](./ems_2024_25_day_05_title_of_notebook_day_05_notebook.ipynb#exercise-9)
#     * [ ]   [<font color=blue>Section 2 of Day 05 notebook</font>](./ems_2024_25_day_05_title_of_notebook_day_05_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 05 notebook</font>](./ems_2024_25_day_05_title_of_notebook_day_05_notebook.ipynb#exercise-10)
#
# * [ ]   [<font color=blue>Day 06 — title of day 06 notebook</font>](./ems_2024_25_day_06_title_of_notebook_day_06_notebook.ipynb#title-of-day-06-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 06 notebook</font>](./ems_2024_25_day_06_title_of_notebook_day_06_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 06 notebook</font>](./ems_2024_25_day_06_title_of_notebook_day_06_notebook.ipynb#exercise-11)
#     * [ ]   [<font color=blue>Section 2 of Day 06 notebook</font>](./ems_2024_25_day_06_title_of_notebook_day_06_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 06 notebook</font>](./ems_2024_25_day_06_title_of_notebook_day_06_notebook.ipynb#exercise-12)
#
# * [ ]   [<font color=blue>Day 07 — title of day 07 notebook</font>](./ems_2024_25_day_07_title_of_notebook_day_07_notebook.ipynb#title-of-day-07-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 07 notebook</font>](./ems_2024_25_day_07_title_of_notebook_day_07_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 07 notebook</font>](./ems_2024_25_day_07_title_of_notebook_day_07_notebook.ipynb#exercise-13)
#     * [ ]   [<font color=blue>Section 2 of Day 07 notebook</font>](./ems_2024_25_day_07_title_of_notebook_day_07_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 07 notebook</font>](./ems_2024_25_day_07_title_of_notebook_day_07_notebook.ipynb#exercise-14)
#
# * [ ]   [<font color=blue>Day 08 — title of day 08 notebook</font>](./ems_2024_25_day_08_title_of_notebook_day_08_notebook.ipynb#title-of-day-08-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 08 notebook</font>](./ems_2024_25_day_08_title_of_notebook_day_08_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 08 notebook</font>](./ems_2024_25_day_08_title_of_notebook_day_08_notebook.ipynb#exercise-15)
#     * [ ]   [<font color=blue>Section 2 of Day 08 notebook</font>](./ems_2024_25_day_08_title_of_notebook_day_08_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 08 notebook</font>](./ems_2024_25_day_08_title_of_notebook_day_08_notebook.ipynb#exercise-16)
#
# * [ ]   [<font color=blue>Day 09 — title of day 09 notebook</font>](./ems_2024_25_day_09_title_of_notebook_day_09_notebook.ipynb#title-of-day-09-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 09 notebook</font>](./ems_2024_25_day_09_title_of_notebook_day_09_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 09 notebook</font>](./ems_2024_25_day_09_title_of_notebook_day_09_notebook.ipynb#exercise-17)
#     * [ ]   [<font color=blue>Section 2 of Day 09 notebook</font>](./ems_2024_25_day_09_title_of_notebook_day_09_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 09 notebook</font>](./ems_2024_25_day_09_title_of_notebook_day_09_notebook.ipynb#exercise-18)
#
# * [ ]   [<font color=blue>Day 10 — title of day 10 notebook</font>](./ems_2024_25_day_10_title_of_notebook_day_10_notebook.ipynb#title-of-day-10-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 10 notebook</font>](./ems_2024_25_day_10_title_of_notebook_day_10_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 10 notebook</font>](./ems_2024_25_day_10_title_of_notebook_day_10_notebook.ipynb#exercise-19)
#     * [ ]   [<font color=blue>Section 2 of Day 10 notebook</font>](./ems_2024_25_day_10_title_of_notebook_day_10_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 10 notebook</font>](./ems_2024_25_day_10_title_of_notebook_day_10_notebook.ipynb#exercise-20)
#
# * [ ]   [<font color=blue>Day 11 — title of day 11 notebook</font>](./ems_2024_25_day_11_title_of_notebook_day_11_notebook.ipynb#title-of-day-11-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 11 notebook</font>](./ems_2024_25_day_11_title_of_notebook_day_11_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 11 notebook</font>](./ems_2024_25_day_11_title_of_notebook_day_11_notebook.ipynb#exercise-21)
#     * [ ]   [<font color=blue>Section 2 of Day 11 notebook</font>](./ems_2024_25_day_11_title_of_notebook_day_11_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 11 notebook</font>](./ems_2024_25_day_11_title_of_notebook_day_11_notebook.ipynb#exercise-22)
#
# * [ ]   [<font color=blue>Day 12 — title of day 12 notebook</font>](./ems_2024_25_day_12_title_of_notebook_day_12_notebook.ipynb#title-of-day-12-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 12 notebook</font>](./ems_2024_25_day_12_title_of_notebook_day_12_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 12 notebook</font>](./ems_2024_25_day_12_title_of_notebook_day_12_notebook.ipynb#exercise-23)
#     * [ ]   [<font color=blue>Section 2 of Day 12 notebook</font>](./ems_2024_25_day_12_title_of_notebook_day_12_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 12 notebook</font>](./ems_2024_25_day_12_title_of_notebook_day_12_notebook.ipynb#exercise-24)
#
# * [ ]   [<font color=blue>Day 13 — title of day 13 notebook</font>](./ems_2024_25_day_13_title_of_notebook_day_13_notebook.ipynb#title-of-day-13-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 13 notebook</font>](./ems_2024_25_day_13_title_of_notebook_day_13_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 13 notebook</font>](./ems_2024_25_day_13_title_of_notebook_day_13_notebook.ipynb#exercise-25)
#     * [ ]   [<font color=blue>Section 2 of Day 13 notebook</font>](./ems_2024_25_day_13_title_of_notebook_day_13_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 13 notebook</font>](./ems_2024_25_day_13_title_of_notebook_day_13_notebook.ipynb#exercise-26)
#
# * [ ]   [<font color=blue>Day 14 — title of day 14 notebook</font>](./ems_2024_25_day_14_title_of_notebook_day_14_notebook.ipynb#title-of-day-14-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 14 notebook</font>](./ems_2024_25_day_14_title_of_notebook_day_14_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 14 notebook</font>](./ems_2024_25_day_14_title_of_notebook_day_14_notebook.ipynb#exercise-27)
#     * [ ]   [<font color=blue>Section 2 of Day 14 notebook</font>](./ems_2024_25_day_14_title_of_notebook_day_14_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 14 notebook</font>](./ems_2024_25_day_14_title_of_notebook_day_14_notebook.ipynb#exercise-28)
#
# * [ ]   [<font color=blue>Day 15 — title of day 15 notebook</font>](./ems_2024_25_day_15_title_of_notebook_day_15_notebook.ipynb#title-of-day-15-notebook)
#     * [ ]   [<font color=blue>Section 1 of Day 15 notebook</font>](./ems_2024_25_day_15_title_of_notebook_day_15_notebook.ipynb#section-1)
#         * [ ]   [<font color=green>Exercises in Day 15 notebook</font>](./ems_2024_25_day_15_title_of_notebook_day_15_notebook.ipynb#exercise-29)
#     * [ ]   [<font color=blue>Section 2 of Day 15 notebook</font>](./ems_2024_25_day_15_title_of_notebook_day_15_notebook.ipynb#section-2)
#         * [ ]   [<font color=green>Exercises in Day 15 notebook</font>](./ems_2024_25_day_15_title_of_notebook_day_15_notebook.ipynb#exercise-30)
